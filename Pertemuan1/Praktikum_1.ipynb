# %% [markdown]
# <a href="https://colab.research.google.com/github/Bisminee/Pembelajaran-Mesin/blob/main/Praktikum_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install mne
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
