# %%
# %pip install pyprep
# %pip install scipy
# %pip install wandb
# %pip install scikit-learn
# %pip install pyecg --no-deps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Penjelasan Library
# - pyprep digunakan dalam memproses sinyal EEG(Electroencephalography) secara otomatis
#
# - scipy digunakan untuk menyediakan algoritma matematika dan komputasi ilmiah, biasanya sering dipakai di ekosistem data science
#
# - wandb digunakan untuk mencatat, memantau, dan mengelola seluruh eksperimen ML dan Deep Learning
#
# - scikit-learn digunakan untuk proses dari ML, meliputi preprocessing, feature scaling, Algortima ML, Dimensional Reduction, dan Model Evaluation & validation
#
#
# - pyecg digunakan untuk analisis sinyal rekam jantung atau ECG, tadi sempat eror karena yang diinstal versinya terlalu lama, sehingga menggunakan tambahan scikit-learn dan --no-deps, ini membuat penginstalan pyecg diinstal tanpa dependensi sehingga tidak terjadi override versi pustaka

# %% [markdown]
# # Bagian 2
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# ## Jawaban
# 1. Tim peneliti Indonesia diduga melakukan manipulasi riset di sebuah konferensi ilmiah internasional di Denmark. sejumlah periset dari Indonesia diduga melakukan manipulasi dalam konferensi ilmiah internasional untuk para ahli pneumonia dunia pada 17-21 Mei 2026 di Kopenhagen, Denmark.(https://www.kompas.id/artikel/peneliti-indonesia-diduga-manipulasi-riset-ai-menguji-integritas-kampus)
#
# hal ini tentu melanggar etika dari peneliti untuk memastikan integritas peneliti Permendikbudristek Nomor 39 Tahun 2021 (https://peraturan.go.id/files/bn1363-2021.pdf)
#
# Secara hukum pun melanggar UU ITE pasal 35 (https://jdih.komdigi.go.id/produk_hukum/view/id/167/t/undangundang+nomor+11+tahun+2008)
#
# 2. Prediksi dari World Economic Forum, pusat data AI "mengonsumsi" air sama dengan penggunaan harian 5 juta orang pada tahun 2030 untuk keperluan pendinginan, sekitar 450 juta galon. Air yng digunakan di tahun 2022 mencapai 292 juta galon.
#
# Kebutuhan listrik untuk menjalankan AI sendiri diprediksi akan mengonsumsi 945 TWh pada tahun 2030 dan pada tahun 2024 mengonsumsi 415 TWh. Hingga tahun 2030, AI sendiri menyumbang permintaan sekitar 20% dari total permintaan kebutuhan listrik, sedangkan suplai listrik masih menggunakan bahan bakar fosil sekitar 40% dari permintaan baru(https://www.weforum.org/stories/artificial-intelligence/ai-energy-nexus-ai-future/)
