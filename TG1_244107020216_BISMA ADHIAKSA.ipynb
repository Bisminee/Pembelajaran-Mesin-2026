# %%
# %pip install pyprep
# %pip install scipy
# %pip install wandb
# %pip install pyecg
# Out:
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.5 MB 874.9 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/7.5 MB 1.4 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/7.5 MB 1.4 MB/s eta 0:00:05
#    ------------ --------------------------- 2.4/7.5 MB 2.1 MB/s eta 0:00:03
#    -------------------- ------------------- 3.9/7.5 MB 3.0 MB/s eta 0:00:02
#    ------------------------------ --------- 5.8/7.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  7.3/7.5 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 4.2 MB/s eta 0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [mne]
#    ------------- -------------------------- 1/3 [mne]
# ...

# %%
# Out:
#   Cell In[3], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
